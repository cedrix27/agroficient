# %% [markdown]
# # Agroficient - Seasonal Model Training (Colab)
#
# Ce notebook entraîne un modèle saisonnier (RandomForest) puis exporte `seasonal_model.joblib`.

# %%
# !pip install -q scikit-learn pandas joblib earthengine-api

# %% [markdown]
# ## 1) Monter Google Drive (optionnel)

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# ## 2) Cloner le repo (ou uploader tes fichiers)

# %%
# Remplace l'URL par ton repo
# !git clone https://github.com/your-org/your-repo.git /content/agroficient

# %% [markdown]
# ## 3) Authentifier Earth Engine

# %%
import ee
ee.Authenticate()

# %%
# Remplace par ton projet GCP
EE_PROJECT_ID = 'youtub-486403'
ee.Initialize(project=EE_PROJECT_ID)

# %% [markdown]
# ## 4) Générer le dataset d'entraînement

# %%
# %cd /content/agroficient
# !python backend/ml/build_training_dataset.py --output backend/ml/training_dataset.csv --start-year 2014 --end-year 2025 --seasons JAS,OND,MAM

# %% [markdown]
# ## 5) Entraîner le modèle

# %%
# !python backend/ml/train_onset_seasonal.py --input backend/ml/training_dataset.csv --output backend/models/seasonal_model.joblib

# %% [markdown]
# ## 6) Télécharger l'artifact modèle

# %%
from google.colab import files
files.download('/content/agroficient/backend/models/seasonal_model.joblib')
